# %%
# pip install covasim
# pip install pyRAPL

"""
Note: requires running on Linux machine. 
I don't think the class cluster works bc not python, can't run on WSL either bc WSL doesn't have direct hardware access?
Try running on VM instead? or on a computer that actually has linux.
"""

import covasim as cv
import pyRAPL

pyRAPL.setup() 

@pyRAPL.measureit
def runCova():
    sim = cv.Sim()
    sim.run()

runCova()
